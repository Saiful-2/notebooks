# %% [markdown]
# <a href="https://colab.research.google.com/github/Saiful-2/notebooks/blob/main/canada_per_capita_income_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Predict Canada's per capita income in the year 2020 using Linear Regression.
#
# Dataset: canada_per_capita_income.csv

# %% [markdown]
# #  Step 1: Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Step 2: Load Dataset

# %%
url = "https://raw.githubusercontent.com/Saiful-2/datasets/main/canada_per_capita_income.csv"

df = pd.read_csv(url)

df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %% [markdown]
# # Step 3: View Dataset Information

# %%
df.shape
# Out:
# (47, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 884.0 bytes

# %%
df.describe()
# Out:
#               year  per capita income (US$)
# count    47.000000                47.000000
# mean   1993.000000             18920.137063
# std      13.711309             12034.679438
# min    1970.000000              3399.299037
# 25%    1981.500000              9526.914515
# 50%    1993.000000             16426.725480
# 75%    2004.500000             27458.601420
# max    2016.000000             42676.468370

# %% [markdown]
# # Step 4: Visualize the Data

# %%
plt.scatter(df['year'], df['per capita income (US$)'])
plt.xlabel("Year")
plt.ylabel("Per Capita Income (US$)")
plt.title("Canada Per Capita Income")
plt.show()

# %% [markdown]
# # Step 5: Prepare Data

# %%
# Independent Variable (X)
X = df[['year']]

# %%
# Dependent Variable (y)
y = df['per capita income (US$)']

# %% [markdown]
# # Step 6: Create and Train Linear Regression Model

# %%
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Step 7: Predict Income for Year 2020

# %%
prediction = model.predict([[2020]])

prediction
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %% [markdown]
# # Final Predicted Value
#
# The predicted per capita income for Canada in 2020 is approximately:
#
# ✅ 41288.69 US Dollars
